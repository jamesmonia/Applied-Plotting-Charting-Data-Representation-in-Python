# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
plt.style.available
# Out:
# ['grayscale',
#  'seaborn-colorblind',
#  'seaborn-bright',
#  'seaborn-deep',
#  'seaborn-pastel',
#  'classic',
#  'seaborn-muted',
#  'seaborn-darkgrid',
#  'seaborn-white',
#  'seaborn-paper',
#  'seaborn-dark',
#  'seaborn-whitegrid',
#  'dark_background',
#  'seaborn-poster',
#  'ggplot',
#  'seaborn-ticks',
#  'seaborn-dark-palette',
#  'seaborn-notebook',
#  'bmh',
#  'seaborn-talk',
#  'fivethirtyeight',
#  'seaborn']

# %%
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)

# %%
df = pd.DataFrame({'A': np.random.randn(365).cumsum(0), 
                   'B': np.random.randn(365).cumsum(0) + 20,
                   'C': np.random.randn(365).cumsum(0) - 20}, 
                  index=pd.date_range('1/1/2017', periods=365))
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot('A','B',kind='scatter') #x,y,kind
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
redux = df.plot.scatter('A','C',c='B',s=df['B'],colormap='viridis')
#returns a subplot, which can be used in other matplotlib pyplot stuff
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig1, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,sharex=False,sharey=False)
#axes[0,0] = redux
#ax1 = df.plot.scatter('A','C',c='B',s=df['B'],colormap='viridis')
fig1.gca() = redux
# Out:
#   File "<ipython-input-56-7edec09c30f9>", line 4
#     fig1.gca() = redux
#                       ^
# SyntaxError: can't assign to function call

# %%
ax = df.plot.scatter('A','C',c='B',s=df['B'],colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hexbin('A','B',colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist(alpha=0.6)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
pd.tools.plotting.scatter_matrix(iris);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
pd.tools.plotting.parallel_coordinates(iris,'Name',colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#seaborn

# %%
np.random.seed(1234)
v1 = pd.Series(np.random.normal(0,10,1000),name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000),name='v2' )

# %%
v1.head()
# Out:
# 0     4.714352
# 1   -11.909757
# 2    14.327070
# 3    -3.126519
# 4    -7.205887
# Name: v1, dtype: float64

# %%
plt.figure()
plt.hist(v1,alpha=0.7,bins=np.arange(-50,150,5),label='v1')
plt.hist(v2,alpha=0.7,bins=np.arange(-50,150,5),label='v2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
v1.hist(alpha=0.7,bins=np.arange(-50,150,5))
v2.hist(alpha=0.7,bins=np.arange(-50,150,5))
#same output
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
plt.hist([v1,v2],histtype='barstacked',normed=True)
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
sns.distplot(v3,hist_kws={'color':'Teal'},kde_kws={'color':'Navy'})
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
grid = sns.jointplot(v1,v2,alpha=0.4)
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(v1,v2,kind='hex')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.jointplot(v1,v2,kind='kde',space=0)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
sns.pairplot(iris,hue='Name',diag_kind='kde')
#keep it to 4x4 otherwise it gets to be too much
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(12,8))
plt.subplot(121) #same as 1,2,1
sns.swarmplot('Name','PetalLength',data=iris)
plt.subplot(122)
sns.violinplot('Name','PetalLength',data=iris)
# Out:
# <img src="data:image/png;base64,..." width="852">

# %%
plt.figure() #figsize=(12,12)
plt.subplot(141) #same as 1,2,1
iris[['PetalWidth','PetalLength']].hist()
#plt.subplot(121)
#sns.violinplot('Name','PetalLength',data=iris)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7b7c37d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7b79cf400>]], dtype=object)
